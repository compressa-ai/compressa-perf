# %%
import sys

sys.path.append('../src')

# %%
import requests
import tqdm

import pickle

with open("/Users/morgachev/Downloads/cmpr_splits.pkl", "rb") as f:
    docs = pickle.load(f)
    
X = "\n\n\n".join([x.page_content for x in docs])
X = \
f"""
Суммаризируй следующий текст:
{X}
"""

# %%
response = requests.post(
  url='http://localhost:5555/v1/chat/completions',
  headers={
    "accept": "application/json",
    "Content-Type": "application/json"
  },
  json={
    "model": "Compressa-Llama3.1-8B",
    "prompt": X
  }
)

# %%
response.json()
# Out:
# {'object': 'error',
# ...

# %%
from openai import OpenAI

# %%
API_KEY = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJNSUwgVGVhbSIsImlhdCI6MTcyMTg2NTYwMCwiZXhwIjoxNzUzNDAxNjAwLCJhdWQiOiJxZHJhbnQubWlsLXRlYW0ucnUiLCJzdWIiOiJ1c2VyQGFwaS5xZHJhbnQubWlsLXRlYW0ucnUiLCJ2YWxpZCI6IjEiLCJyZWFkeSI6IjEifQ.7AiMfRH_FzQHGRCA1-v1XDbfDiwNAHuCkKcXoI0T3DM"

client = OpenAI(
    api_key = API_KEY,
    base_url = 'http://localhost:5555/v1'
)

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant. Answer in Russian.",
        },
        {
            "role": "user",
            "content": X
        }
    ],
    model="Compressa-LLM",
)
print(chat_completion.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/mil/compressa-perf/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:69, in map_httpcore_exceptions()
#      68 try:
# ---> 69     yield
#      70 except Exception as exc:
#
# File ~/mil/compressa-perf/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/mil/compressa-perf/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
# ...

# %%
chat_completion
# Out:
# ChatCompletion(id='chat-fbd242908316499595e75c3ef0c196c2', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='Приказ Минцифры России от 31 января 2022 года № 75 об утверждении российской системы и плана нумерации был в последний раз обновлен 17 августа 2023 года и номером 713. Это документ регулирует отношения в сфере связи, определяет структуру и планы нумерации, которые используются для идентификации и обработки телефонных и телеграфных вызовов, а также для организации работы подвижных и фиксированных сетей связи. \n\nВ документе представлены детали систем нумерации, включая коды страны, коды зон нумерации и коды доступа, определены правила вызова экстренных служб и определены требования к операторам поисковых систем и социальных сетей. \n\nВажно обратить внимание на следующие ключевые моменты из приложения к документу:  \n- потеря активов и собственного капитала в течение анализируемого периода;  \n- общий уровень текущей ликвидн
# ...

# %%
len(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 len(X)
#
# NameError: name 'X' is not defined

# %%
API_KEY = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJNSUwgVGVhbSIsImlhdCI6MTcyMTg2NTYwMCwiZXhwIjoxNzUzNDAxNjAwLCJhdWQiOiJxZHJhbnQubWlsLXRlYW0ucnUiLCJzdWIiOiJ1c2VyQGFwaS5xZHJhbnQubWlsLXRlYW0ucnUiLCJ2YWxpZCI6IjEiLCJyZWFkeSI6IjEifQ.7AiMfRH_FzQHGRCA1-v1XDbfDiwNAHuCkKcXoI0T3DM"
from openai import OpenAI
client = OpenAI(
    api_key = API_KEY,
    base_url = "https://api.qdrant.mil-team.ru/chat-1/v1"
)

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant. Answer in Russian.",
        },
        {
            "role": "user",
            "content": X,
        }
    ],
    model="Compressa-Llama3.1-8B",
)
print(chat_completion.choices[0].message.content)
# Out:
# Данный текст представляет собой совокупность юридических положений, регулирующих отношения в сфере информации, информационных технологий и защиты информации на территории Российской Федерации. Он состоит из двух частей: первой части описываются основные принципы правового регулирования отношений в этой сфере, а вторая часть содержит конкретные положения о государственном регулировании в сфере применения информационных технологий, включая создание единой системы доменных имен, ограничение доступа к сайтам в сети "Интернет", защиты информации, а также порядок ограничения доступа к информации, распространяемой с нарушением закона и требований законодательства Российской Федерации о выборах и референдумах.
#
# ...

# %%
# Out:
# 407959
